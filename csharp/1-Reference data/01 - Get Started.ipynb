// %% [markdown]
// # [C#] - Get Started: Retrieving Static Data
//
// This tutorial serves as an introductory guide for utilizing Ganymede's **StaticDataService** with C#.
// <br><br>
// While not exhaustive, it provides essential steps for retrieving static data. Users can learn how to send queries by asset type, employing different codes and searching techniques.
// <br><br>
// This tutorial lays the groundwork for utilizing the *StaticDataService* effectively in C# applications.

// %% [markdown]
// ## Step 1 : Setup and import packages
// Before proceeding, make sure to set up and import the appropriate packages.

// %%
#i "nuget: file:///home/jovyan/.nuget/packages/"
#i "nuget: https://api.nuget.org/v3/index.json"
#r "nuget: Systemathics.Apis, 2.39.*"
// Out:
// <div>
//     <div id='dotnet-interactive-this-cell-4181.Microsoft.DotNet.Interactive.Http.HttpPort' style='display: none'>
//         The below script needs to be able to find the current output cell; this is an easy method to get it.
//     </div>
//     <script type='text/javascript'>
// async function probeAddresses(probingAddresses) {
//     function timeout(ms, promise) {
//         return new Promise(function (resolve, reject) {
//             setTimeout(function () {
//                 reject(new Error('timeout'))
//             }, ms)
//             promise.then(resolve, reject)
//         })
//     }
//
//     if (Array.isArray(probingAddresses)) {
//         for (let i = 0; i < probingAddresses.length; i++) {
//
//             let rootUrl = probingAddresses[i];
//
//             if (!rootUrl.endsWith('/')) {
//                 rootUrl = `${rootUrl}/`;
//             }
//
//             try {
//                 let response = await timeout(1000, fetch(`${rootUrl}discovery`, {
//                     method: 'POST',
//                     cache: 'no-cache',
//                     mode: 'cors',
//                     timeout: 1000,
//                     headers: {
//                         'Content-Type': 'text/plain'
//                     },
//                     body: probingAddresses[i]
//                 }));
//
//                 if (response.status == 200) {
//                     return rootUrl;
//                 }
//             }
//             catch (e) { }
//         }
//     }
// }
//
// function loadDotnetInteractiveApi() {
//     probeAddresses(["http://100.64.0.238:49152/", "http://127.0.0.1:49152/"])
//         .then((root) => {
//         // use probing to find host url and api resources
//         // load interactive helpers and language services
//         let dotnetInteractiveRequire = require.config({
//         context: '4181.Microsoft.DotNet.Interactive.Http.HttpPort',
//                 paths:
//             {
//                 'dotnet-interactive': `${root}resources`
//                 }
//         }) || require;
//
//             window.dotnetInteractiveRequire = dotnetInteractiveRequire;
//
//             window.configureRequireFromExtension = function(extensionName, extensionCacheBuster) {
//                 let paths = {};
//                 paths[extensionName] = `${root}extensions/${extensionName}/resources/`;
//
//                 let internalRequire = require.config({
//                     context: extensionCacheBuster,
//                     paths: paths,
//                     urlArgs: `cacheBuster=${extensionCacheBuster}`
//                     }) || require;
//
//                 return internalRequire
//             };
//
//             dotnetInteractiveRequire([
//                     'dotnet-interactive/dotnet-interactive'
//                 ],
//                 function (dotnet) {
//                     dotnet.init(window);
//                 },
//                 function (error) {
//                     console.log(error);
//                 }
//             );
//         })
//         .catch(error => {console.log(error);});
//     }
//
// // ensure `require` is available globally
// if ((typeof(require) !==  typeof(Function)) || (typeof(require.config) !== typeof(Function))) {
//     let require_script = document.createElement('script');
//     require_script.setAttribute('src', 'https://cdnjs.cloudflare.com/ajax/libs/require.js/2.3.6/require.min.js');
//     require_script.setAttribute('type', 'text/javascript');
//
//
//     require_script.onload = function() {
//         loadDotnetInteractiveApi();
//     };
//
//     document.getElementsByTagName('head')[0].appendChild(require_script);
// }
// else {
//     loadDotnetInteractiveApi();
// }
//
//     </script>
// </div>
// <div><div><strong>Restore sources</strong><ul><li><span> file:///home/jovyan/.nuget/packages/</span></li><li><span> https://api.nuget.org/v3/index.json</span></li></ul></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Systemathics.Apis, 2.39.2</span></li></ul></div></div>

// %%
// Import required packages
// Systemathics packages
using Systemathics.Apis.Type.Shared.V1;
using Systemathics.Apis.Helpers;
using Systemathics.Apis.Services.StaticData.V1;

// Essential packages 
using Google.Protobuf.WellKnownTypes;
using Google.Type;
using Grpc.Net.Client;
using Grpc.Core;

// %% [markdown]
// ## Step 2: Retrieve a valid token
// To proceed, you need to retrieve a valid authentication *token*.
// <br><br>The following code snippets demonstrate how to obtain an authentication *token* and prepare the API request. This involves opening the communication *channel* and adding the token to the request header:

// %%
// Get authentication token
var headers = TokenHelpers.GetTokenAsMetaData();

// Create communication channel
var channel = ChannelHelpers.GetChannel();

// %% [markdown]
// ## Step 3: Call Static Data Service
// With the setup complete, we're now ready to initiate the service.

// %%
// Instantiate the service
var service = new StaticDataService.StaticDataServiceClient(channel);

// %% [markdown]
// ## Step 4: Create and process request

// %% [markdown]
// ### 4.1 Retrieve Equities
// To request equities for example, you need to specify the AssetType as <i>`AssetType.Equity`</i> in the static data request.

// %% [markdown]
// To retrieve all available asset types, please refer to the [Ganymede documentation](https://ganymede.cloud/docs/#systemathics/apis/services/static_data/v1/assettype).
//
// The following snippet displays all the available values of the AssetType enum.

// %%
// Display all AssetType Enum Values
Console.WriteLine("All AssetType Enum Values:");
foreach (AssetType assetType in System.Enum.GetValues(typeof(AssetType)))
{
    Console.WriteLine(assetType);
}
// Out:
// All AssetType Enum Values:
// Unspecified
// All
// Equity
// Future
// Etf
// Index
// Crypto
// Forex
// Option
// Bond
// Cds

// %% [markdown]
// In the following snippet, we demonstrate how to request all equities as an example. By default, the maximum records returned is set to 500.
//
// To handle larger datasets, *pagination* is necessary. Please refer to the sample pagination implementation for guidance.

// %%
// Generate request
var request = new StaticDataRequest
{
  AssetType = AssetType.Equity //<-- Insert the asset type here
};

// %%
// handle the response
var reply = service.StaticData(request, headers);

// %%
// Display the response : counts
display($"Total count = {reply.Equity.TotalCount}");
display($"Found count = {reply.Equity.Assets.Count}");
// Out:
// Total count = 593
// Found count = 500

// %%
// Display the response : assets
display(reply.Equity.Assets)
// Out:
// <table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>{ &quot;identifier&quot;: { &quot;exchange&quot;: &quot;XPAR&quot;, &quot;ticker&quot;: &quot;VIE&quot; }, &quot;type&quot;: &quot;Equity&quot;, &quot;active&quot;: true, &quot;primary&quot;: &quot;XPAR&quot;, &quot;operating&quot;: &quot;XPAR&quot;, &quot;name&quot;: &quot;VEOLIA ENVIRON.&quot;, &quot;currency&quot;: &quot;EUR&quot;, &quot;country&quot;: &quot;FR&quot;, &quot;tickSizeRule&quot;: [ { &quot;tick&quot;: 0.0001 }, { &quot;price&quot;: 1, &quot;tick&quot;: 0.0005 }, { &quot;price&quot;: 2, &quot;tick&quot;: 0.001 }, { &quot;pr...</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Identifier</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>{ &quot;exchange&quot;: &quot;XPAR&quot;, &quot;ticker&quot;: &quot;VIE&quot; }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Exchange</td><td><div class="dni-plaintext"><pre>XPAR</pre></div></td></tr><tr><td>Ticker</td><td><div class="dni-plaintext"><pre>VIE</pre></div></td></tr><tr><td>Provider</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>Type</td><td><div class="dni-plaintext"><pre>Equity</pre></div></td></tr><tr><td>Active</td><td><div class="dni-plaintext"><pre>True</pre></div></td></tr><tr><td>Primary</td><td><div class="dni-plaintext"><pre>XPAR</pre></div></td></tr><tr><td>Operating</td><td><div class="dni-plaintext"><pre>XPAR</pre></div></td></tr><tr><td>Name</td><td><div class="dni-plaintext"><pre>VEOLIA ENVIRON.</pre></div></td></tr><tr><td>Currency</td><td><div class="dni-plaintext"><pre>EUR</pre></div></td></tr><tr><td>Country</td><td><div class="dni-plaintext"><pre>FR</pre></div></td></tr><tr><td>TickSizeRule</td><td><table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>{ &quot;tick&quot;: 0.0001 }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Price</td><td><div class="dni-plaintext"><pre>0</pre></div></td></tr><tr><td>Tick</td><td><div class="dni-plaintext"><pre>0.0001</pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>1</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>{ &quot;price&quot;: 1, &quot;tick&quot;: 0.0005 }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Price</td><td><div class="dni-plaintext"><pre>1</pre></div></td></tr><tr><td>Tick</td><td><div class="dni-plaintext"><pre>0.0005</pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>2</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>{ &quot;price&quot;: 2, &quot;tick&quot;: 0.001 }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Price</td><td><div class="dni-plaintext"><pre>2</pre></div></td></tr><tr><td>Tick</td><td><div class="dni-plaintext"><pre>0.001</pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>3</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>{ &quot;price&quot;: 5, &quot;tick&quot;: 0.002 }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Price</td><td><div class="dni-plaintext"><pre>5</pre></div></td></tr><tr><td>Tick</td><td><div class="dni-plaintext"><pre>0.002</pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>4</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>{ &quot;price&quot;: 10, &quot;tick&quot;: 0.005 }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Price</td><td><div class="dni-plaintext"><pre>10</pre></div></td></tr><tr><td>Tick</td><td><div class="dni-plaintext"><pre>0.005</pre></div></td></tr></tbody></table></div></d ...

// %% [markdown]
// ### 4.2 Retrieve by Name
// To retrieve data for a specific asset name, include the asset name in the request.

// %%
var request = new StaticDataRequest
{
  AssetType = AssetType.Equity,
  Name = "Apple" //<-- Include the asset name here
};

// %%
var reply = service.StaticData(request, headers);

// %%
display(reply.Equity.Assets)
// Out:
// <table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>{ &quot;identifier&quot;: { &quot;exchange&quot;: &quot;XNAS&quot;, &quot;ticker&quot;: &quot;AAPL&quot; }, &quot;type&quot;: &quot;Equity&quot;, &quot;active&quot;: true, &quot;primary&quot;: &quot;XNAS&quot;, &quot;operating&quot;: &quot;XNAS&quot;, &quot;name&quot;: &quot;Apple Inc&quot;, &quot;currency&quot;: &quot;USD&quot;, &quot;country&quot;: &quot;US&quot;, &quot;tickSizeRule&quot;: [ { &quot;tick&quot;: 0.0001 } ], &quot;index&quot;: [ &quot;NDX-XNAS&quot; ], &quot;calendar&quot;: &quot;XNAS&quot;, &quot;description&quot;: &quot;Apple&#39;s bu...</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Identifier</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>{ &quot;exchange&quot;: &quot;XNAS&quot;, &quot;ticker&quot;: &quot;AAPL&quot; }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Exchange</td><td><div class="dni-plaintext"><pre>XNAS</pre></div></td></tr><tr><td>Ticker</td><td><div class="dni-plaintext"><pre>AAPL</pre></div></td></tr><tr><td>Provider</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>Type</td><td><div class="dni-plaintext"><pre>Equity</pre></div></td></tr><tr><td>Active</td><td><div class="dni-plaintext"><pre>True</pre></div></td></tr><tr><td>Primary</td><td><div class="dni-plaintext"><pre>XNAS</pre></div></td></tr><tr><td>Operating</td><td><div class="dni-plaintext"><pre>XNAS</pre></div></td></tr><tr><td>Name</td><td><div class="dni-plaintext"><pre>Apple Inc</pre></div></td></tr><tr><td>Currency</td><td><div class="dni-plaintext"><pre>USD</pre></div></td></tr><tr><td>Country</td><td><div class="dni-plaintext"><pre>US</pre></div></td></tr><tr><td>TickSizeRule</td><td><table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>{ &quot;tick&quot;: 0.0001 }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Price</td><td><div class="dni-plaintext"><pre>0</pre></div></td></tr><tr><td>Tick</td><td><div class="dni-plaintext"><pre>0.0001</pre></div></td></tr></tbody></table></div></details></td></tr></tbody></table></td></tr><tr><td>Index</td><td><div class="dni-plaintext"><pre>[ NDX-XNAS ]</pre></div></td></tr><tr><td>Calendar</td><td><div class="dni-plaintext"><pre>XNAS</pre></div></td></tr><tr><td>Description</td><td><div class="dni-plaintext"><pre>Apple&#39;s business primarily runs around its flagship iPhone. However the Services portfolio that includes cloud services App store Apple Music AppleCare Apple Pay &amp; licensing and other services which become the cash cow. Moreover non-iPhone devices like Apple Watch and AirPod have gained significant traction. In fact Apple dominates the Wearables and Hearables markets due to the growing adoption of Watch and AirPods. Solid uptake of Apple Watch also helps Apple to strengthen its presence in the personal health monitoring space. Apple also designs manufactures and sells iPad MacBookand HomePod. These devices are powered by software applications including iOS macOS watchOS and tvOS operating systems. Apple&#39;s other services include subscription-based Apple News Apple Card Apple Arcade new Apple TV app Apple TV channels and Apple TV a new subscription service.</pre></div></td></tr><tr><td>Open</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>&quot;34200s&quot;</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Seconds</td><td><div class="dni-plaintext"><pre>34200</pre></div></td></tr><tr><td>Nanos</td><td><div class="dni-plaintext"><pre>0</pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>Close</td><td><details class="dni-treeview"><summary>< ...
// .dni-code-hint {
//     font-style: italic;
//     overflow: hidden;
//     white-space: nowrap;
// }
// .dni-treeview {
//     white-space: nowrap;
// }
// .dni-treeview td {
//     vertical-align: top;
//     text-align: start;
// }
// details.dni-treeview {
//     padding-left: 1em;
// }
// table td {
//     text-align: start;
// }
// table tr {
//     vertical-align: top;
//     margin: 0em 0px;
// }
// table tr td pre
// {
//     vertical-align: top !important;
//     margin: 0em 0px !important;
// }
// table th {
//     text-align: start;
// }
// </style>

// %% [markdown]
// ### 4.3 Retrieve by Exchange
// To retrieve data for a specific exchange mic code, include the exchange code in the request.
// <br><br>
// In the snippet below, we also demonstrate how to specify the desired number of records using the *Count* property and the starting index using the *Start* property in the *request*.

// %%
var request = new StaticDataRequest
{
  AssetType = AssetType.Equity,
  Exchange = "XNAS", //<-- Include the exchange mic code
  Count = 10, // Select the first n elements
  Start = 5 // Starting from element index at i
};

// %%
var reply = service.StaticData(request, headers);

// %%
display(reply.Equity.Assets)
// Out:
// <table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>{ &quot;identifier&quot;: { &quot;exchange&quot;: &quot;XNAS&quot;, &quot;ticker&quot;: &quot;TTD&quot; }, &quot;type&quot;: &quot;Equity&quot;, &quot;active&quot;: true, &quot;primary&quot;: &quot;XNAS&quot;, &quot;operating&quot;: &quot;XNAS&quot;, &quot;name&quot;: &quot;Trade Desk Inc&quot;, &quot;currency&quot;: &quot;USD&quot;, &quot;country&quot;: &quot;US&quot;, &quot;tickSizeRule&quot;: [ { &quot;tick&quot;: 0.0001 } ], &quot;index&quot;: [ &quot;NDX-XNAS&quot; ], &quot;calendar&quot;: &quot;XNAS&quot;, &quot;description&quot;: &quot;The Tr...</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Identifier</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>{ &quot;exchange&quot;: &quot;XNAS&quot;, &quot;ticker&quot;: &quot;TTD&quot; }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Exchange</td><td><div class="dni-plaintext"><pre>XNAS</pre></div></td></tr><tr><td>Ticker</td><td><div class="dni-plaintext"><pre>TTD</pre></div></td></tr><tr><td>Provider</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>Type</td><td><div class="dni-plaintext"><pre>Equity</pre></div></td></tr><tr><td>Active</td><td><div class="dni-plaintext"><pre>True</pre></div></td></tr><tr><td>Primary</td><td><div class="dni-plaintext"><pre>XNAS</pre></div></td></tr><tr><td>Operating</td><td><div class="dni-plaintext"><pre>XNAS</pre></div></td></tr><tr><td>Name</td><td><div class="dni-plaintext"><pre>Trade Desk Inc</pre></div></td></tr><tr><td>Currency</td><td><div class="dni-plaintext"><pre>USD</pre></div></td></tr><tr><td>Country</td><td><div class="dni-plaintext"><pre>US</pre></div></td></tr><tr><td>TickSizeRule</td><td><table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>{ &quot;tick&quot;: 0.0001 }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Price</td><td><div class="dni-plaintext"><pre>0</pre></div></td></tr><tr><td>Tick</td><td><div class="dni-plaintext"><pre>0.0001</pre></div></td></tr></tbody></table></div></details></td></tr></tbody></table></td></tr><tr><td>Index</td><td><div class="dni-plaintext"><pre>[ NDX-XNAS ]</pre></div></td></tr><tr><td>Calendar</td><td><div class="dni-plaintext"><pre>XNAS</pre></div></td></tr><tr><td>Description</td><td><div class="dni-plaintext"><pre>The Trade Desk Inc. is a provider of technology platform for advertising. The company through self-service cloud-based platform ad buyers create manage and optimize data-driven digital advertising campaigns which includes display video audio native and social on a multitude of devices such as computers mobile devices and connected TV. It operates primarily in the United States Europe and Asia. The Trade Desk Inc. is headquartered in Ventura CA.</pre></div></td></tr><tr><td>Open</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>&quot;34200s&quot;</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Seconds</td><td><div class="dni-plaintext"><pre>34200</pre></div></td></tr><tr><td>Nanos</td><td><div class="dni-plaintext"><pre>0</pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>Close</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>&quot;57600s&quot;</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Seconds</td><td><div class="dni-plaintext"><pre>57600</pre></div></td></tr><tr><td>Nanos</td><td><div class="dni-plaintext"><pre>0</pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>TimeZone</td><td><div class="dni-plaintext"><pre>ET</pre></div></td></tr><tr><td>LotSize</td><td><div cl ...

// %% [markdown]
// ### 4.4 Retrieve by Ticker
// To retrieve data for a specific ticker, include the ticker code in the request.

// %%
var request = new StaticDataRequest
{
  AssetType = AssetType.Equity,
  Ticker = "BNP"
};

// %%
var reply = service.StaticData(request, headers);

// %%
display(reply.Equity.Assets)
// Out:
// <table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>{ &quot;identifier&quot;: { &quot;exchange&quot;: &quot;XPAR&quot;, &quot;ticker&quot;: &quot;BNP&quot; }, &quot;type&quot;: &quot;Equity&quot;, &quot;active&quot;: true, &quot;primary&quot;: &quot;XPAR&quot;, &quot;operating&quot;: &quot;XPAR&quot;, &quot;name&quot;: &quot;BNP PARIBAS ACT.A&quot;, &quot;currency&quot;: &quot;EUR&quot;, &quot;country&quot;: &quot;FR&quot;, &quot;tickSizeRule&quot;: [ { &quot;tick&quot;: 0.0001 }, { &quot;price&quot;: 1, &quot;tick&quot;: 0.0002 }, { &quot;price&quot;: 2, &quot;tick&quot;: 0.0005 }, { ...</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Identifier</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>{ &quot;exchange&quot;: &quot;XPAR&quot;, &quot;ticker&quot;: &quot;BNP&quot; }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Exchange</td><td><div class="dni-plaintext"><pre>XPAR</pre></div></td></tr><tr><td>Ticker</td><td><div class="dni-plaintext"><pre>BNP</pre></div></td></tr><tr><td>Provider</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>Type</td><td><div class="dni-plaintext"><pre>Equity</pre></div></td></tr><tr><td>Active</td><td><div class="dni-plaintext"><pre>True</pre></div></td></tr><tr><td>Primary</td><td><div class="dni-plaintext"><pre>XPAR</pre></div></td></tr><tr><td>Operating</td><td><div class="dni-plaintext"><pre>XPAR</pre></div></td></tr><tr><td>Name</td><td><div class="dni-plaintext"><pre>BNP PARIBAS ACT.A</pre></div></td></tr><tr><td>Currency</td><td><div class="dni-plaintext"><pre>EUR</pre></div></td></tr><tr><td>Country</td><td><div class="dni-plaintext"><pre>FR</pre></div></td></tr><tr><td>TickSizeRule</td><td><table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>{ &quot;tick&quot;: 0.0001 }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Price</td><td><div class="dni-plaintext"><pre>0</pre></div></td></tr><tr><td>Tick</td><td><div class="dni-plaintext"><pre>0.0001</pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>1</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>{ &quot;price&quot;: 1, &quot;tick&quot;: 0.0002 }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Price</td><td><div class="dni-plaintext"><pre>1</pre></div></td></tr><tr><td>Tick</td><td><div class="dni-plaintext"><pre>0.0002</pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>2</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>{ &quot;price&quot;: 2, &quot;tick&quot;: 0.0005 }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Price</td><td><div class="dni-plaintext"><pre>2</pre></div></td></tr><tr><td>Tick</td><td><div class="dni-plaintext"><pre>0.0005</pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>3</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>{ &quot;price&quot;: 5, &quot;tick&quot;: 0.001 }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Price</td><td><div class="dni-plaintext"><pre>5</pre></div></td></tr><tr><td>Tick</td><td><div class="dni-plaintext"><pre>0.001</pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>4</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>{ &quot;price&quot;: 10, &quot;tick&quot;: 0.002 }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Price</td><td><div class="dni-plaintext"><pre>10</pre></div></td></tr><tr><td>Tick</td><td><div class="dni-plaintext"><pre>0.002</pre></div></td></tr></tbody></table></div></de ...

// %% [markdown]
// ### 4.5 Retrieve by ISIN
// To retrieve data for a specific ISIN, include the ISIN code in the request.

// %%
var request = new StaticDataRequest
{
  AssetType = AssetType.Equity,
  Isin = "FR0000131104" //<-- Insert the ISIN code here
};

// %%
var reply = service.StaticData(request, headers);

// %%
display(reply.Equity.Assets)
// Out:
// <table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>{ &quot;identifier&quot;: { &quot;exchange&quot;: &quot;XPAR&quot;, &quot;ticker&quot;: &quot;BNP&quot; }, &quot;type&quot;: &quot;Equity&quot;, &quot;active&quot;: true, &quot;primary&quot;: &quot;XPAR&quot;, &quot;operating&quot;: &quot;XPAR&quot;, &quot;name&quot;: &quot;BNP PARIBAS ACT.A&quot;, &quot;currency&quot;: &quot;EUR&quot;, &quot;country&quot;: &quot;FR&quot;, &quot;tickSizeRule&quot;: [ { &quot;tick&quot;: 0.0001 }, { &quot;price&quot;: 1, &quot;tick&quot;: 0.0002 }, { &quot;price&quot;: 2, &quot;tick&quot;: 0.0005 }, { ...</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Identifier</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>{ &quot;exchange&quot;: &quot;XPAR&quot;, &quot;ticker&quot;: &quot;BNP&quot; }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Exchange</td><td><div class="dni-plaintext"><pre>XPAR</pre></div></td></tr><tr><td>Ticker</td><td><div class="dni-plaintext"><pre>BNP</pre></div></td></tr><tr><td>Provider</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>Type</td><td><div class="dni-plaintext"><pre>Equity</pre></div></td></tr><tr><td>Active</td><td><div class="dni-plaintext"><pre>True</pre></div></td></tr><tr><td>Primary</td><td><div class="dni-plaintext"><pre>XPAR</pre></div></td></tr><tr><td>Operating</td><td><div class="dni-plaintext"><pre>XPAR</pre></div></td></tr><tr><td>Name</td><td><div class="dni-plaintext"><pre>BNP PARIBAS ACT.A</pre></div></td></tr><tr><td>Currency</td><td><div class="dni-plaintext"><pre>EUR</pre></div></td></tr><tr><td>Country</td><td><div class="dni-plaintext"><pre>FR</pre></div></td></tr><tr><td>TickSizeRule</td><td><table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>{ &quot;tick&quot;: 0.0001 }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Price</td><td><div class="dni-plaintext"><pre>0</pre></div></td></tr><tr><td>Tick</td><td><div class="dni-plaintext"><pre>0.0001</pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>1</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>{ &quot;price&quot;: 1, &quot;tick&quot;: 0.0002 }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Price</td><td><div class="dni-plaintext"><pre>1</pre></div></td></tr><tr><td>Tick</td><td><div class="dni-plaintext"><pre>0.0002</pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>2</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>{ &quot;price&quot;: 2, &quot;tick&quot;: 0.0005 }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Price</td><td><div class="dni-plaintext"><pre>2</pre></div></td></tr><tr><td>Tick</td><td><div class="dni-plaintext"><pre>0.0005</pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>3</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>{ &quot;price&quot;: 5, &quot;tick&quot;: 0.001 }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Price</td><td><div class="dni-plaintext"><pre>5</pre></div></td></tr><tr><td>Tick</td><td><div class="dni-plaintext"><pre>0.001</pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>4</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>{ &quot;price&quot;: 10, &quot;tick&quot;: 0.002 }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Price</td><td><div class="dni-plaintext"><pre>10</pre></div></td></tr><tr><td>Tick</td><td><div class="dni-plaintext"><pre>0.002</pre></div></td></tr></tbody></table></div></de ...

// %% [markdown]
// ### 4.6 Retrieve by Ticker + Exchange
// To retrieve data for a specific Ticker and Exchange, include both codes in the request. In the sample bewlo, when including different properties in the request, they are combined using the "and" logic.

// %%
// The service also enables to query with multiple filters as follows
var request = new StaticDataRequest
{
  AssetType = AssetType.Equity,
  Ticker = "AAPL", //<-- The ticker code
  Exchange = "XNAS" //<-- The exchange mic code
};

// %%
var reply = service.StaticData(request, headers);

// %%
display(reply.Equity.Assets)
// Out:
// <table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>{ &quot;identifier&quot;: { &quot;exchange&quot;: &quot;XNAS&quot;, &quot;ticker&quot;: &quot;AAPL&quot; }, &quot;type&quot;: &quot;Equity&quot;, &quot;active&quot;: true, &quot;primary&quot;: &quot;XNAS&quot;, &quot;operating&quot;: &quot;XNAS&quot;, &quot;name&quot;: &quot;Apple Inc&quot;, &quot;currency&quot;: &quot;USD&quot;, &quot;country&quot;: &quot;US&quot;, &quot;tickSizeRule&quot;: [ { &quot;tick&quot;: 0.0001 } ], &quot;index&quot;: [ &quot;NDX-XNAS&quot; ], &quot;calendar&quot;: &quot;XNAS&quot;, &quot;description&quot;: &quot;Apple&#39;s bu...</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Identifier</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>{ &quot;exchange&quot;: &quot;XNAS&quot;, &quot;ticker&quot;: &quot;AAPL&quot; }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Exchange</td><td><div class="dni-plaintext"><pre>XNAS</pre></div></td></tr><tr><td>Ticker</td><td><div class="dni-plaintext"><pre>AAPL</pre></div></td></tr><tr><td>Provider</td><td><div class="dni-plaintext"><pre>&lt;null&gt;</pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>Type</td><td><div class="dni-plaintext"><pre>Equity</pre></div></td></tr><tr><td>Active</td><td><div class="dni-plaintext"><pre>True</pre></div></td></tr><tr><td>Primary</td><td><div class="dni-plaintext"><pre>XNAS</pre></div></td></tr><tr><td>Operating</td><td><div class="dni-plaintext"><pre>XNAS</pre></div></td></tr><tr><td>Name</td><td><div class="dni-plaintext"><pre>Apple Inc</pre></div></td></tr><tr><td>Currency</td><td><div class="dni-plaintext"><pre>USD</pre></div></td></tr><tr><td>Country</td><td><div class="dni-plaintext"><pre>US</pre></div></td></tr><tr><td>TickSizeRule</td><td><table><thead><tr><th><i>index</i></th><th>value</th></tr></thead><tbody><tr><td>0</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>{ &quot;tick&quot;: 0.0001 }</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Price</td><td><div class="dni-plaintext"><pre>0</pre></div></td></tr><tr><td>Tick</td><td><div class="dni-plaintext"><pre>0.0001</pre></div></td></tr></tbody></table></div></details></td></tr></tbody></table></td></tr><tr><td>Index</td><td><div class="dni-plaintext"><pre>[ NDX-XNAS ]</pre></div></td></tr><tr><td>Calendar</td><td><div class="dni-plaintext"><pre>XNAS</pre></div></td></tr><tr><td>Description</td><td><div class="dni-plaintext"><pre>Apple&#39;s business primarily runs around its flagship iPhone. However the Services portfolio that includes cloud services App store Apple Music AppleCare Apple Pay &amp; licensing and other services which become the cash cow. Moreover non-iPhone devices like Apple Watch and AirPod have gained significant traction. In fact Apple dominates the Wearables and Hearables markets due to the growing adoption of Watch and AirPods. Solid uptake of Apple Watch also helps Apple to strengthen its presence in the personal health monitoring space. Apple also designs manufactures and sells iPad MacBookand HomePod. These devices are powered by software applications including iOS macOS watchOS and tvOS operating systems. Apple&#39;s other services include subscription-based Apple News Apple Card Apple Arcade new Apple TV app Apple TV channels and Apple TV a new subscription service.</pre></div></td></tr><tr><td>Open</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>&quot;34200s&quot;</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>Seconds</td><td><div class="dni-plaintext"><pre>34200</pre></div></td></tr><tr><td>Nanos</td><td><div class="dni-plaintext"><pre>0</pre></div></td></tr></tbody></table></div></details></td></tr><tr><td>Close</td><td><details class="dni-treeview"><summary>< ...
// .dni-code-hint {
//     font-style: italic;
//     overflow: hidden;
//     white-space: nowrap;
// }
// .dni-treeview {
//     white-space: nowrap;
// }
// .dni-treeview td {
//     vertical-align: top;
//     text-align: start;
// }
// details.dni-treeview {
//     padding-left: 1em;
// }
// table td {
//     text-align: start;
// }
// table tr {
//     vertical-align: top;
//     margin: 0em 0px;
// }
// table tr td pre
// {
//     vertical-align: top !important;
//     margin: 0em 0px !important;
// }
// table th {
//     text-align: start;
// }
// </style>
